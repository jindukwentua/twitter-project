# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from May 1st 2021 to 30th Juy 2021 for 'Vaccine'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"clean water since:2021-01-01 until:2022-04-08 near:"Cape Town"').get_items(),10000))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duration: {} '.format(end_time - start_time))
# Out:
# Duration: 0:00:05.815841

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/PamRenaud/status/151215418...
# 1  https://twitter.com/nanotrac/status/1512055234...
# 2  https://twitter.com/CentreEnvRights/status/151...
# 3  https://twitter.com/SpotlightNSP/status/151199...
# 4  https://twitter.com/RollandBere/status/1511250...
#
#                        date  \
# 0 2022-04-07 19:43:46+00:00
# 1 2022-04-07 13:10:35+00:00
# 2 2022-04-07 10:44:42+00:00
# 3 2022-04-07 09:29:11+00:00
# 4 2022-04-05 07:52:06+00:00
#
#                                              content  \
# 0  Opinion: Time to take clean indoor air as seri...
# 1  Solar Nanowire-Nanotube Purification Filter Of...
# 2  “Human wellbeing depends fundamentally on the ...
# 3  JUST IN: Time to take clean indoor air as seri...
# 4  We are living in a world where women have easi...
#
#                                      renderedContent                   id  \
# 0  Opinion: Time to take clean indoor air as seri...  1512154184208027648
# 1  Solar Nanowire-Nanotube Purification Filter Of...  1512055234448674821
# 2  “Human wellbeing depends fundamentally on the ...  1512018524696465412
# 3  JUST IN: Time to take clean indoor air as seri...  1511999519273242624
# 4  We are living in a world where women have easi...  1511250311918276610
#
#                                                 user  replyCount  \
# 0  {'username': 'PamRenaud', 'id': 396445294, 'di...           0
# 1  {'username': 'nanotrac', 'id': 417213067, 'dis...           0
# 2  {'username': 'CentreEnvRights', 'id': 35566624...           0
# 3  {'username': 'SpotlightNSP', 'id': 73431340893...           2
# 4  {'username': 'RollandBere', 'id': 123274442348...           0
#
#    retweetCount  likeCount  quoteCount  ...  \
# 0             0          0           0  ...
# 1             4          3           0  ...
# 2             4         11           1  ...
# 3             9         18           3  ...
# 4             1          9           0  ...
#
#                                                media retweetedTweet  \
# 0                                               None           None
# 1                                               None           None
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 3                                               None           None
# 4                                               None           None
#
#   quotedTweet inReplyToTweetId inReplyToUser  \
# 0        None              NaN          None
# 1        None              NaN          None
# 2        None              NaN          None
# 3        None              NaN          None
# 4        None              NaN          None
#
#                                       mentionedUsers coordinates place  \
# 0                                               None        None  None
# 1  [{'username': 'SciTechDaily1', 'id': 415863226...        None  None
# 2                                               None        None  None
# 3  [{'username': 'SECTION27news', 'id': 706825897...        None  None
# 4                                               None        None  None
#
#                               hashtags cashtags
# 0                                 None     None
# 1  [Science, Technology, SciTechDaily]     None
# 2                                 None     None
# 3                       [tuberculosis]     None
# 4                                 None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((20, 27),
#  Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'replyCount',
#         'retweetCount', 'likeCount', 'quoteCount', 'conversationId', 'lang',
#         'source', 'sourceUrl', 'sourceLabel', 'outlinks', 'tcooutlinks',
#         'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#         'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#         'cashtags'],
#        dtype='object'))

# %%
tweets.to_csv('clean_water_capetown.csv')

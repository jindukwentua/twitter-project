# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from May 1st 2021 to 30th Juy 2021 for 'Vaccine'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"#water since:2021-01-01 until:2022-04-08 near:"Lagos"').get_items(),10000))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duration: {} '.format(end_time - start_time))
# Out:
# Duration: 0:10:34.763615

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/meeforreal/status/15122160...
# 1  https://twitter.com/SpecialSlim_/status/151220...
# 2  https://twitter.com/LtdMaslow/status/151220935...
# 3  https://twitter.com/alamoriade/status/15122093...
# 4  https://twitter.com/AmaechiOgbonna2/status/151...
#
#                        date  \
# 0 2022-04-07 23:49:29+00:00
# 1 2022-04-07 23:23:23+00:00
# 2 2022-04-07 23:23:01+00:00
# 3 2022-04-07 23:22:52+00:00
# 4 2022-04-07 23:18:28+00:00
#
#                                              content  \
# 0  @Ilyasu_Asiya See ehn….better drink plenty wat...
# 1  @phoenix_ink_ Lol I remember that time you coo...
# 2  Ogun State Mass Transit: Gov Abiodun unveils W...
# 3                  @davido Problem be like ice water
# 4  Mehn movies weren't my thing while growing up,...
#
#                                      renderedContent                   id  \
# 0  @Ilyasu_Asiya See ehn….better drink plenty wat...  1512216019967766529
# 1  @phoenix_ink_ Lol I remember that time you coo...  1512209452602216456
# 2  Ogun State Mass Transit: Gov Abiodun unveils W...  1512209358414831618
# 3                  @davido Problem be like ice water  1512209320775237636
# 4  Mehn movies weren't my thing while growing up,...  1512208215710355461
#
#                                                 user  replyCount  \
# 0  {'username': 'meeforreal', 'id': 1149995895234...           0
# 1  {'username': 'SpecialSlim_', 'id': 2733066387,...           1
# 2  {'username': 'LtdMaslow', 'id': 14642956868671...           0
# 3  {'username': 'alamoriade', 'id': 1512204143179...           0
# 4  {'username': 'AmaechiOgbonna2', 'id': 12113517...           0
#
#    retweetCount  likeCount  quoteCount  ...  media retweetedTweet quotedTweet  \
# 0             0          0           0  ...   None           None        None
# 1             0          1           1  ...   None           None        None
# 2             0          0           0  ...   None           None        None
# 3             0          0           0  ...   None           None        None
# 4             0          0           0  ...   None           None        None
#
#   inReplyToTweetId                                      inReplyToUser  \
# 0     1.512215e+18  {'username': 'Ilyasu_Asiya', 'id': 94596294298...
# 1     1.512209e+18  {'username': 'phoenix_ink_', 'id': 15083215184...
# 2              NaN                                               None
# 3     1.512162e+18  {'username': 'davido', 'id': 192947735, 'displ...
# 4              NaN                                               None
#
#                                       mentionedUsers coordinates place  \
# 0  [{'username': 'Ilyasu_Asiya', 'id': 9459629429...        None  None
# 1  [{'username': 'phoenix_ink_', 'id': 1508321518...        None  None
# 2                                               None        None  None
# 3  [{'username': 'davido', 'id': 192947735, 'disp...        None  None
# 4                                               None        None  None
#
#   hashtags cashtags
# 0     None     None
# 1     None     None
# 2     None     None
# 3     None     None
# 4     None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((10000, 27),
#  Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'replyCount',
#         'retweetCount', 'likeCount', 'quoteCount', 'conversationId', 'lang',
#         'source', 'sourceUrl', 'sourceLabel', 'outlinks', 'tcooutlinks',
#         'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#         'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#         'cashtags'],
#        dtype='object'))

# %%
tweets.to_csv('water_lagos.csv')

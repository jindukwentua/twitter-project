# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from May 1st 2021 to 30th Juy 2021 for 'Vaccine'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"no water supply since:2021-01-01 until:2022-04-08 near:"Cape Town"').get_items(),10000))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duration: {} '.format(end_time - start_time))
# Out:
# Duration: 0:00:04.852344

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/DanSch1984/status/14675908...
# 1  https://twitter.com/DanSch1984/status/14673779...
# 2  https://twitter.com/DanSch1984/status/14673744...
# 3  https://twitter.com/DanSch1984/status/14450422...
# 4  https://twitter.com/MichJBagley/status/1431671...
#
#                        date  \
# 0 2021-12-05 20:25:04+00:00
# 1 2021-12-05 06:18:59+00:00
# 2 2021-12-05 06:05:02+00:00
# 3 2021-10-04 15:04:43+00:00
# 4 2021-08-28 17:33:05+00:00
#
#                                              content  \
# 0  @CityofCT Good evening. Still no water supply....
# 1  @CityofCT Good morning. No water supply at 141...
# 2  @CityofCT Good morning. We have no water suppl...
# 3  Good day @CityofCT @CityofCTAlerts no water su...
# 4  Your request for No Water Supply at Van Eyssen...
#
#                                      renderedContent                   id  \
# 0  @CityofCT Good evening. Still no water supply....  1467590871638028290
# 1  @CityofCT Good morning. No water supply at 141...  1467377944821653504
# 2  @CityofCT Good morning. We have no water suppl...  1467374434159894528
# 3  Good day @CityofCT @CityofCTAlerts no water su...  1445042204108541955
# 4  Your request for No Water Supply at Van Eyssen...  1431671188573626373
#
#                                                 user  replyCount  \
# 0  {'username': 'DanSch1984', 'id': 7553054774965...           0
# 1  {'username': 'DanSch1984', 'id': 7553054774965...           0
# 2  {'username': 'DanSch1984', 'id': 7553054774965...           0
# 3  {'username': 'DanSch1984', 'id': 7553054774965...           1
# 4  {'username': 'MichJBagley', 'id': 1438978848, ...           0
#
#    retweetCount  likeCount  quoteCount  ...  media retweetedTweet quotedTweet  \
# 0             0          0           0  ...   None           None        None
# 1             0          0           0  ...   None           None        None
# 2             0          0           0  ...   None           None        None
# 3             0          0           0  ...   None           None        None
# 4             0          0           0  ...   None           None        None
#
#   inReplyToTweetId                                      inReplyToUser  \
# 0              NaN                                               None
# 1              NaN                                               None
# 2     1.466629e+18  {'username': 'DanSch1984', 'id': 7553054774965...
# 3              NaN                                               None
# 4              NaN                                               None
#
#                                       mentionedUsers  \
# 0  [{'username': 'CityofCT', 'id': 132437983, 'di...
# 1  [{'username': 'CityofCT', 'id': 132437983, 'di...
# 2  [{'username': 'CityofCT', 'id': 132437983, 'di...
# 3  [{'username': 'CityofCT', 'id': 132437983, 'di...
# 4  [{'username': 'CityofCT', 'id': 132437983, 'di...
#
#                                          coordinates  \
# 0  {'longitude': 18.589352, 'latitude': -33.9412227}
# 1  {'longitude': 18.589352, 'latitude': -33.9412227}
# 2  {'longitude': 18.589352, 'latitude': -33.9412227}
# 3  {'longitude': 18.589352, 'latitude': -33.9412227}
# 4  {'longitude': 18.5572133, 'latitude': -33.944865}
#
#                                                place hashtags cashtags
# 0  {'fullName': 'Bellville, South Africa', 'name'...     None     None
# 1  {'fullName': 'Bellville, South Africa', 'name'...     None     None
# 2  {'fullName': 'Bellville, South Africa', 'name'...     None     None
# 3  {'fullName': 'Bellville, South Africa', 'name'...     None     None
# 4  {'fullName': 'Parow, South Africa', 'name': 'P...     None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((8, 27),
#  Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'replyCount',
#         'retweetCount', 'likeCount', 'quoteCount', 'conversationId', 'lang',
#         'source', 'sourceUrl', 'sourceLabel', 'outlinks', 'tcooutlinks',
#         'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#         'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#         'cashtags'],
#        dtype='object'))

# %%
tweets.to_csv('no_water_supply_capetown.csv')

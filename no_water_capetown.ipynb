# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from May 1st 2021 to 30th Juy 2021 for 'Vaccine'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"no water since:2021-01-01 until:2022-04-08 near:"Cape Town"').get_items(),10000))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duration: {} '.format(end_time - start_time))
# Out:
# Duration: 0:00:18.814248

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/dani_ray_george/status/151...
# 1  https://twitter.com/dynagbnnmm/status/15121195...
# 2  https://twitter.com/5ReeceSwartz5/status/15120...
# 3  https://twitter.com/hills007/status/1511979167...
# 4  https://twitter.com/Lukhokhanya/status/1511599...
#
#                        date  \
# 0 2022-04-07 19:46:48+00:00
# 1 2022-04-07 17:26:11+00:00
# 2 2022-04-07 12:48:18+00:00
# 3 2022-04-07 08:08:19+00:00
# 4 2022-04-06 06:58:55+00:00
#
#                                              content  \
# 0  @JHBWater What is happening in Morningside and...
# 1  @MoT_1972 @SeeYanda Ok I understand SA is not ...
# 2  This country been through the most\n- No water...
# 3  @CityofCT Please advise what is happening with...
# 4  @zsimayi Water scarcity is a shame in SA and I...
#
#                                      renderedContent                   id  \
# 0  @JHBWater What is happening in Morningside and...  1512154947407781891
# 1  @MoT_1972 @SeeYanda Ok I understand SA is not ...  1512119561235185666
# 2  This country been through the most\n- No water...  1512049629298413570
# 3  @CityofCT Please advise what is happening with...  1511979167335817219
# 4  @zsimayi Water scarcity is a shame in SA and I...  1511599315013505025
#
#                                                 user  replyCount  \
# 0  {'username': 'dani_ray_george', 'id': 32752876...           0
# 1  {'username': 'dynagbnnmm', 'id': 9985161717911...           2
# 2  {'username': '5ReeceSwartz5', 'id': 748749020,...           0
# 3  {'username': 'hills007', 'id': 764829104638160...           1
# 4  {'username': 'Lukhokhanya', 'id': 446860858, '...           1
#
#    retweetCount  likeCount  quoteCount  ...  media retweetedTweet quotedTweet  \
# 0             0          0           0  ...   None           None        None
# 1             0          1           0  ...   None           None        None
# 2             0          1           0  ...   None           None        None
# 3             0          0           0  ...   None           None        None
# 4             0          1           0  ...   None           None        None
#
#   inReplyToTweetId                                      inReplyToUser  \
# 0              NaN                                               None
# 1     1.512116e+18  {'username': 'MoT_1972', 'id': 369614868, 'dis...
# 2              NaN                                               None
# 3              NaN                                               None
# 4     1.511597e+18  {'username': 'zsimayi', 'id': 2722891763, 'dis...
#
#                                       mentionedUsers coordinates place  \
# 0  [{'username': 'JHBWater', 'id': 244959564, 'di...        None  None
# 1  [{'username': 'MoT_1972', 'id': 369614868, 'di...        None  None
# 2                                               None        None  None
# 3  [{'username': 'CityofCT', 'id': 132437983, 'di...        None  None
# 4  [{'username': 'zsimayi', 'id': 2722891763, 'di...        None  None
#
#   hashtags cashtags
# 0     None     None
# 1     None     None
# 2     None     None
# 3     None     None
# 4     None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((96, 27),
#  Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'replyCount',
#         'retweetCount', 'likeCount', 'quoteCount', 'conversationId', 'lang',
#         'source', 'sourceUrl', 'sourceLabel', 'outlinks', 'tcooutlinks',
#         'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#         'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#         'cashtags'],
#        dtype='object'))

# %%
tweets.to_csv('no_water_capetown.csv')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from January 1st 2021 to Date'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"water crisis since:2021-01-01 until:2022-04-08 near:"Cape Town"').get_items(),10000))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duration: {} '.format(end_time - start_time))
# Out:
# Duration: 0:00:05.738057

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/CPTWaterCrisis/status/1511...
# 1  https://twitter.com/TheCapeArgus/status/151028...
# 2  https://twitter.com/TheCapeGreek/status/151024...
# 3  https://twitter.com/FutureWaterUCT/status/1509...
# 4  https://twitter.com/CPTWaterCrisis/status/1509...
#
#                        date  \
# 0 2022-04-05 11:50:56+00:00
# 1 2022-04-02 15:56:41+00:00
# 2 2022-04-02 13:29:01+00:00
# 3 2022-04-01 12:19:54+00:00
# 4 2022-04-01 11:50:53+00:00
#
#                                              content  \
# 0  The latest Water Crisis South Africa! https://...
# 1  ICYMI THIS WEEK | The Newlands Swimming Pool i...
# 2  First thought on London: so many nice cars, an...
# 3  Lessons from the Cape Town water crisis and th...
# 4  The latest Water Crisis South Africa! https://...
#
#                                      renderedContent                   id  \
# 0  The latest Water Crisis South Africa! news.wat...  1511310414616965123
# 1  ICYMI THIS WEEK | The Newlands Swimming Pool i...  1510285097894830082
# 2  First thought on London: so many nice cars, an...  1510247934813691907
# 3  Lessons from the Cape Town water crisis and th...  1509868152951296002
# 4  The latest Water Crisis South Africa! news.wat...  1509860852995960836
#
#                                                 user  replyCount  \
# 0  {'username': 'CPTWaterCrisis', 'id': 822208128...           0
# 1  {'username': 'TheCapeArgus', 'id': 213170220, ...           0
# 2  {'username': 'TheCapeGreek', 'id': 99628751507...           0
# 3  {'username': 'FutureWaterUCT', 'id': 799611091...           1
# 4  {'username': 'CPTWaterCrisis', 'id': 822208128...           0
#
#    retweetCount  likeCount  quoteCount  ...  media retweetedTweet quotedTweet  \
# 0             0          0           0  ...   None           None        None
# 1             0          3           1  ...   None           None        None
# 2             0          0           0  ...   None           None        None
# 3             2          2           0  ...   None           None        None
# 4             0          0           0  ...   None           None        None
#
#   inReplyToTweetId inReplyToUser  \
# 0              NaN          None
# 1              NaN          None
# 2              NaN          None
# 3              NaN          None
# 4              NaN          None
#
#                                       mentionedUsers coordinates place  \
# 0  [{'username': 'WaterInstSA', 'id': 71835375714...        None  None
# 1                                               None        None  None
# 2                                               None        None  None
# 3  [{'username': 'kirsty_carden', 'id': 816624309...        None  None
# 4  [{'username': 'SaveTheVaal', 'id': 78050694433...        None  None
#
#         hashtags cashtags
# 0  [water, wisa]     None
# 1           None     None
# 2           None     None
# 3           None     None
# 4           None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((20, 27),
#  Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'replyCount',
#         'retweetCount', 'likeCount', 'quoteCount', 'conversationId', 'lang',
#         'source', 'sourceUrl', 'sourceLabel', 'outlinks', 'tcooutlinks',
#         'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#         'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#         'cashtags'],
#        dtype='object'))

# %%
tweets.to_csv('water_crisis_capetown.csv')

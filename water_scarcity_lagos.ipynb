# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from May 1st 2021 to 30th Juy 2021 for 'Vaccine'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"Water scarcity since:2021-01-01 until:2022-04-08 near:"Lagos"').get_items(),5 ))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duration: {} '.format(end_time - start_time))
# Out:
# Duration: 0:00:01.702269

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/sesorafrica/status/1512032...
# 1  https://twitter.com/mmsplusnews/status/1511697...
# 2  https://twitter.com/mediaoppconcept/status/151...
# 3  https://twitter.com/BoomPurity/status/15106059...
# 4  https://twitter.com/Olawale_Hassan/status/1510...
#
#                        date  \
# 0 2022-04-07 11:38:23+00:00
# 1 2022-04-06 13:27:47+00:00
# 2 2022-04-06 11:37:44+00:00
# 3 2022-04-03 13:11:42+00:00
# 4 2022-04-02 14:15:37+00:00
#
#                                              content  \
# 0  Extreme weather events, land degradation and w...
# 1  Water Day 2022: Addressing Acute Water Scarcit...
# 2  Taraba: Jalingo residents groan as water scarc...
# 3  The provision of clean water for domestic use ...
# 4  @Santabellamusic Enugu is suffering from acute...
#
#                                      renderedContent                   id  \
# 0  Extreme weather events, land degradation and w...  1512032032834179078
# 1  Water Day 2022: Addressing Acute Water Scarcit...  1511697175310389257
# 2  Taraba: Jalingo residents groan as water scarc...  1511669480820256773
# 3  The provision of clean water for domestic use ...  1510605965149843457
# 4  @Santabellamusic Enugu is suffering from acute...  1510259661903179778
#
#                                                 user  replyCount  \
# 0  {'username': 'sesorafrica', 'id': 2154635654, ...           0
# 1  {'username': 'mmsplusnews', 'id': 2670030926, ...           0
# 2  {'username': 'mediaoppconcept', 'id': 80093056...           0
# 3  {'username': 'BoomPurity', 'id': 1191009311570...           1
# 4  {'username': 'Olawale_Hassan', 'id': 350323813...           0
#
#    retweetCount  likeCount  quoteCount  ...  \
# 0             3          3           0  ...
# 1             0          0           0  ...
# 2             1          0           0  ...
# 3             1          1           0  ...
# 4             0          1           0  ...
#
#                                                media retweetedTweet  \
# 0  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 1                                               None           None
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 3  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 4                                               None           None
#
#   quotedTweet inReplyToTweetId  \
# 0        None              NaN
# 1        None              NaN
# 2        None              NaN
# 3        None              NaN
# 4        None     1.509381e+18
#
#                                        inReplyToUser  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'username': 'Santabellamusic', 'id': 14907318...
#
#                                       mentionedUsers coordinates place  \
# 0                                               None        None  None
# 1                                               None        None  None
# 2                                               None        None  None
# 3  [{'username': 'followKWSG', 'id': 555419158, '...        None  None
# 4  [{'username': 'Santabellamusic', 'id': 1490731...        None  None
#
#                                             hashtags cashtags
# 0  [sesor, who, worldhealthday2022, OurplanetOurh...     None
# 1                                               None     None
# 2                                               None     None
# 3                                               None     None
# 4                                               None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((0, 0), Index([], dtype='object'))

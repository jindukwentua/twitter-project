# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from May 1st 2021 to 30th Juy 2021 for 'Vaccine'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"#vaccine since:2021-05-01 until:2021-07-30"').get_items(),5 ))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duuration: {} '.format(end_time - start_time))
# Out:
# Duuration: 0:00:03.818885

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/datrufwilfreeu/status/1420...
# 1  https://twitter.com/ignacio1981sala/status/142...
# 2  https://twitter.com/Bdj68Brad/status/142089692...
# 3  https://twitter.com/DrSallan_/status/142089691...
# 4  https://twitter.com/einerdrake/status/14208969...
#
#                        date  \
# 0 2021-07-29 23:59:59+00:00
# 1 2021-07-29 23:59:59+00:00
# 2 2021-07-29 23:59:59+00:00
# 3 2021-07-29 23:59:58+00:00
# 4 2021-07-29 23:59:58+00:00
#
#                                              content  \
# 0  Act Now America: Say NO To Vaccine Passports h...
# 1  So they are forcing my sister-in-law to take t...
# 2  @DAVEWILLISON1 Medical autonomy is a right Dav...
# 3  @_AlexHirsch The fact people are arguing under...
# 4  Find out which vaccine is seeing the most brea...
#
#                                      renderedContent                   id  \
# 0  Act Now America: Say NO To Vaccine Passports s...  1420896922278240256
# 1  So they are forcing my sister-in-law to take t...  1420896922181804032
# 2  @DAVEWILLISON1 Medical autonomy is a right Dav...  1420896920453599234
# 3  @_AlexHirsch The fact people are arguing under...  1420896917958057984
# 4  Find out which vaccine is seeing the most brea...  1420896917316272130
#
#                                                 user  replyCount  \
# 0  {'username': 'datrufwilfreeu', 'id': 939901935...           0
# 1  {'username': 'ignacio1981sala', 'id': 92013753...           0
# 2  {'username': 'Bdj68Brad', 'id': 3010803738, 'd...           0
# 3  {'username': 'DrSallan_', 'id': 77223242720493...           0
# 4  {'username': 'einerdrake', 'id': 19150025, 'di...           0
#
#    retweetCount  likeCount  quoteCount  ...  media retweetedTweet quotedTweet  \
# 0             0          0           0  ...   None           None        None
# 1             0          0           0  ...   None           None        None
# 2             0          0           0  ...   None           None        None
# 3             0          0           0  ...   None           None        None
# 4             0          0           0  ...   None           None        None
#
#   inReplyToTweetId                                      inReplyToUser  \
# 0              NaN                                               None
# 1              NaN                                               None
# 2     1.420882e+18  {'username': 'DAVEWILLISON1', 'id': 777812617,...
# 3     1.420528e+18  {'username': '_AlexHirsch', 'id': 81285400, 'd...
# 4              NaN                                               None
#
#                                       mentionedUsers coordinates place  \
# 0  [{'username': 'standforhealth1', 'id': 1158740...        None  None
# 1                                               None        None  None
# 2  [{'username': 'DAVEWILLISON1', 'id': 777812617...        None  None
# 3  [{'username': '_AlexHirsch', 'id': 81285400, '...        None  None
# 4                                               None        None  None
#
#   hashtags cashtags
# 0     None     None
# 1     None     None
# 2     None     None
# 3     None     None
# 4     None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((5, 27),
#  Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'replyCount',
#         'retweetCount', 'likeCount', 'quoteCount', 'conversationId', 'lang',
#         'source', 'sourceUrl', 'sourceLabel', 'outlinks', 'tcooutlinks',
#         'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#         'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#         'cashtags'],
#        dtype='object'))

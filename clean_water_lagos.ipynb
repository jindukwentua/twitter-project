# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from May 1st 2021 to 30th Juy 2021 for 'Vaccine'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"clean water since:2021-01-01 until:2022-04-08 near:"Lagos"').get_items(),10000))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duration: {} '.format(end_time - start_time))
# Out:
# Duration: 0:00:18.947328

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/Smart_abbey/status/1512170...
# 1  https://twitter.com/homesnshelters/status/1512...
# 2  https://twitter.com/atlas_ng/status/1511989880...
# 3  https://twitter.com/kingzodo/status/1511977533...
# 4  https://twitter.com/timinipereAbaba/status/151...
#
#                        date  \
# 0 2022-04-07 20:50:34+00:00
# 1 2022-04-07 16:26:38+00:00
# 2 2022-04-07 08:50:53+00:00
# 3 2022-04-07 08:01:49+00:00
# 4 2022-04-06 21:18:05+00:00
#
#                                              content  \
# 0                              @Naija_PR Clean water
# 1  NOW SELLING: FOUR(4) BEDROOM LUXURY TERRACES. ...
# 2  Atlas initiative is saying reimagine and all c...
# 3  *N75m Lekki Luxury Duplex*\n\n🔑🔑 4Bedrooms Sem...
# 4  @rotilaw @asemota Lebanese, Indians and Chines...
#
#                                      renderedContent                   id  \
# 0                              @Naija_PR Clean water  1512170993279713284
# 1  NOW SELLING: FOUR(4) BEDROOM LUXURY TERRACES. ...  1512104572130627592
# 2  Atlas initiative is saying reimagine and all c...  1511989880393543681
# 3  *N75m Lekki Luxury Duplex*\n\n🔑🔑 4Bedrooms Sem...  1511977533193007105
# 4  @rotilaw @asemota Lebanese, Indians and Chines...  1511815531753521158
#
#                                                 user  replyCount  \
# 0  {'username': 'Smart_abbey', 'id': 355543284, '...           0
# 1  {'username': 'homesnshelters', 'id': 224755558...           1
# 2  {'username': 'atlas_ng', 'id': 927913390114209...           0
# 3  {'username': 'kingzodo', 'id': 249199431, 'dis...           1
# 4  {'username': 'timinipereAbaba', 'id': 19573728...           2
#
#    retweetCount  likeCount  quoteCount  ...  \
# 0             0          0           0  ...
# 1             2          2           0  ...
# 2             0          4           0  ...
# 3             0          1           0  ...
# 4             0          4           0  ...
#
#                                                media retweetedTweet  \
# 0                                               None           None
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 3  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 4                                               None           None
#
#   quotedTweet inReplyToTweetId  \
# 0        None     1.512092e+18
# 1        None              NaN
# 2        None     1.511989e+18
# 3        None              NaN
# 4        None     1.511812e+18
#
#                                        inReplyToUser  \
# 0  {'username': 'Naija_PR', 'id': 1901298962, 'di...
# 1                                               None
# 2  {'username': 'atlas_ng', 'id': 927913390114209...
# 3                                               None
# 4  {'username': 'rotilaw', 'id': 406824132, 'disp...
#
#                                       mentionedUsers  \
# 0  [{'username': 'Naija_PR', 'id': 1901298962, 'd...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  [{'username': 'rotilaw', 'id': 406824132, 'dis...
#
#                                        coordinates  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3  {'longitude': 3.2131467, 'latitude': 6.4278856}
# 4                                             None
#
#                                                place hashtags cashtags
# 0                                               None     None     None
# 1                                               None     None     None
# 2                                               None  [ATLAS]     None
# 3  {'fullName': 'Lagos, Nigeria', 'name': 'Lagos'...     None     None
# 4                                               None     None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((128, 27),
#  Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'replyCount',
#         'retweetCount', 'likeCount', 'quoteCount', 'conversationId', 'lang',
#         'source', 'sourceUrl', 'sourceLabel', 'outlinks', 'tcooutlinks',
#         'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#         'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#         'cashtags'],
#        dtype='object'))

# %%
tweets.to_csv('clean_water_lagos.csv')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import snscrape.modules.twitter as sntwitter
import plotly.graph_objects as go
from datetime import datetime

# %%
# Noting the time it takes to scrape 50000 tweets

start_time = datetime.now()

#Creating dataframe called 'data' and storing the tweets from May 1st 2021 to 30th Juy 2021 for 'Vaccine'
tweets = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"no water since:2021-01-01 until:2022-04-08 near:"Lagos"').get_items(),10000))

end_time = datetime.now()

# Printing the time taken to scrape these tweets
print('Duration: {} '.format(end_time - start_time))
# Out:
# Duration: 0:00:12.256711

# %%
tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/Inyang_udoka/status/151215...
# 1  https://twitter.com/mrcow_enang/status/1512146...
# 2  https://twitter.com/Mayor_Kreations/status/151...
# 3  https://twitter.com/TheBigBeeb1/status/1511925...
# 4  https://twitter.com/Benedictaochon1/status/151...
#
#                        date  \
# 0 2022-04-07 20:01:21+00:00
# 1 2022-04-07 19:11:48+00:00
# 2 2022-04-07 06:37:52+00:00
# 3 2022-04-07 04:35:04+00:00
# 4 2022-04-06 09:56:14+00:00
#
#                                              content  \
# 0  @Lagoswater @jidesanwoolu good evening, since ...
# 1  @lekzyauto The stress is not funny. 5pm and be...
# 2  Just as water is to human, marketing is to any...
# 3  It's been over a week now since NEPA gave us l...
# 4  NIN wahala in Nigeria but  wait ooo Nigeria to...
#
#                                      renderedContent                   id  \
# 0  @Lagoswater @jidesanwoolu good evening, since ...  1512158608527613953
# 1  @lekzyauto The stress is not funny. 5pm and be...  1512146139302313988
# 2  Just as water is to human, marketing is to any...  1511956404990529539
# 3  It's been over a week now since NEPA gave us l...  1511925500834426884
# 4  NIN wahala in Nigeria but  wait ooo Nigeria to...  1511643939580874753
#
#                                                 user  replyCount  \
# 0  {'username': 'Inyang_udoka', 'id': 192117514, ...           0
# 1  {'username': 'mrcow_enang', 'id': 836124458289...           1
# 2  {'username': 'Mayor_Kreations', 'id': 31154948...           0
# 3  {'username': 'TheBigBeeb1', 'id': 993540458210...           0
# 4  {'username': 'Benedictaochon1', 'id': 11866693...           0
#
#    retweetCount  likeCount  quoteCount  ...  media retweetedTweet quotedTweet  \
# 0             0          0           0  ...   None           None        None
# 1             0          1           0  ...   None           None        None
# 2             0          2           0  ...   None           None        None
# 3             0          0           0  ...   None           None        None
# 4             0          0           0  ...   None           None        None
#
#   inReplyToTweetId                                      inReplyToUser  \
# 0     1.506361e+18  {'username': 'Inyang_udoka', 'id': 192117514, ...
# 1     1.512140e+18  {'username': 'lekzyauto', 'id': 14153402101252...
# 2              NaN                                               None
# 3              NaN                                               None
# 4              NaN                                               None
#
#                                       mentionedUsers  \
# 0  [{'username': 'Lagoswater', 'id': 714787167625...
# 1  [{'username': 'lekzyauto', 'id': 1415340210125...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                        coordinates  \
# 0                                             None
# 1  {'longitude': 2.7063037, 'latitude': 6.3703877}
# 2                                             None
# 3  {'longitude': 3.2131467, 'latitude': 6.4278856}
# 4                                             None
#
#                                                place hashtags cashtags
# 0                                               None     None     None
# 1  {'fullName': 'Lagos, Nigeria', 'name': 'Lagos'...     None     None
# 2                                               None     None     None
# 3  {'fullName': 'Lagos, Nigeria', 'name': 'Lagos'...     None     None
# 4                                               None     None     None
#
# [5 rows x 27 columns]

# %%
tweets.shape, tweets.columns
# Out:
# ((131, 27),
#  Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'replyCount',
#         'retweetCount', 'likeCount', 'quoteCount', 'conversationId', 'lang',
#         'source', 'sourceUrl', 'sourceLabel', 'outlinks', 'tcooutlinks',
#         'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#         'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#         'cashtags'],
#        dtype='object'))

# %%
tweets.to_csv('no_water_lagos.csv')
